# %%
import os
import json
import pandas as pd
import psycopg2
import plotly.express as px

# %%
#Gathering Agrregate Transactional Data#
path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/aggregated/transaction/country/india/state/"
trans_list = os.listdir(path)

columns1 = {"States":[], "Years":[], "Quarter":[], "Transaction_type":[], "Transaction_count":[], "Transaction_amount": []}
for state in trans_list:
    states = path+ state+ "/"
    year_list = os.listdir(states)
    
    for year in year_list:
        year1 = states+ year+ "/"
        file_list = os.listdir(year1)
        #print(file_list)

        for file in file_list:
            file1 = year1+file
            read_data = open(file1, "r")

            data = json.load(read_data)
            for i in data ["data"]["transactionData"]:
                Transaction_type = i["name"]
                count = i["paymentInstruments"][0]["count"]
                amount = i["paymentInstruments"][0]["amount"]
                columns1["Transaction_type"].append(Transaction_type)
                columns1["Transaction_count"].append(count)
                columns1["Transaction_amount"].append(amount)
                columns1["States"].append(state)
                columns1["Years"].append(year)
                columns1["Quarter"].append(int(file.strip(".json")))
aggre_transaction = pd.DataFrame(columns1)

aggre_transaction["States"] = aggre_transaction["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
aggre_transaction["States"] = aggre_transaction["States"].str.title()
aggre_transaction["States"] = aggre_transaction["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
aggre_transaction["States"] = aggre_transaction["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
aggre_transaction["States"] = aggre_transaction["States"].str.replace("-", " ")


#####################################################################################################################################################################
#Gathering Agrregate user Data#
user_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/aggregated/user/country/india/state/"
user_list = os.listdir(user_path)

columns2 = {"States":[], "Years":[], "Quarter":[], "Brands":[], "Transaction_count":[], "Percentage": []}
for state in user_list:
    user_states = user_path+ state+ "/"
    user_year_list = os.listdir(user_states)
    
    for year in user_year_list:
        user_year = user_states+ year+ "/"
        user_file_list = os.listdir(user_year)

        for file in user_file_list:
            user_file1 = user_year+file
            user_read_data = open(user_file1, "r")
            user_data = json.load(user_read_data)
            
            try:
                for i in user_data["data"]["usersByDevice"]:
                    brand = i["brand"]
                    count = i["count"]
                    percentage = i["percentage"]
                    columns2["Brands"].append(brand)
                    columns2["Transaction_count"].append(count)
                    columns2["Percentage"].append(percentage)
                    columns2["States"].append(state)
                    columns2["Years"].append(year)
                    columns2["Quarter"].append(int(file.strip(".json")))

            except:
                pass
aggre_user = pd.DataFrame(columns2)
aggre_user["States"] = aggre_user["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
aggre_user["States"] = aggre_user["States"].str.title()
aggre_user["States"] = aggre_user["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
aggre_user["States"] = aggre_user["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
aggre_user["States"] = aggre_user["States"].str.replace("-", " ")

######################################################################################################################################################################

#Gathering Aggregate Insurance Details
insurance_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/aggregated/insurance/country/india/state/"
insurance_list = os.listdir(insurance_path)
columns4 = {"States":[], "Years":[], "Quarter":[], "Payment_type":[], "Transaction_count":[], "Insurance_amount": []}
for state in insurance_list:
    insurance_states = insurance_path+ state+ "/"
    insurance_year_list = os.listdir(insurance_states)
    
    for year in insurance_year_list:
        insurance_year = insurance_states+ year+ "/"
        insurance_file_list = os.listdir(insurance_year)

        for file in insurance_file_list:
            insurance_file1 = insurance_year+file
            insurance_read_data = open(insurance_file1, "r")
            insurance_data = json.load(insurance_read_data)

            for i in insurance_data["data"]["transactionData"]:
                payment_type = i["name"]
                count = i ["paymentInstruments"] [0] ["count"]
                Insurance_amount = i ["paymentInstruments"] [0] ["amount"]
                columns4["Payment_type"].append(payment_type)
                columns4["Transaction_count"].append(count)
                columns4["Insurance_amount"].append(Insurance_amount)
                columns4["States"].append(state)
                columns4["Years"].append(year)
                columns4["Quarter"].append(int(file.strip(".json")))
aggre_insurance = pd.DataFrame(columns4)

aggre_insurance["States"] = aggre_insurance["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
aggre_insurance["States"] = aggre_insurance["States"].str.replace("andaman-&-nicobar-islands", "Andaman & nicobar islands")
aggre_insurance["States"] = aggre_insurance["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
aggre_insurance["States"] = aggre_insurance["States"].str.replace("-", " ")
aggre_insurance["States"] = aggre_insurance["States"].str.title()

#############################################################################################################################################################################

#Gathering map transaction details
maptrans_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/map/transaction/hover/country/india/state/"
maptrans_list = os.listdir(maptrans_path)
columns3 = {"States":[], "Years":[], "Quarter":[], "Districts":[], "Transaction_count":[], "Amount": []}
for state in maptrans_list:
    maptrans_states = maptrans_path+ state+ "/"
    maptrans_year_list = os.listdir(maptrans_states)
    
    for year in maptrans_year_list:
        maptrans_year = maptrans_states+ year+ "/"
        maptrans_file_list = os.listdir(maptrans_year)

        for file in maptrans_file_list:
            maptrans_file1 = maptrans_year+file
            maptrans_read_data = open(maptrans_file1, "r")
            maptrans_data = json.load(maptrans_read_data)

            for i in maptrans_data["data"]["hoverDataList"]:
                district = i["name"]
                count = i ["metric"] [0] ["count"]
                Amount = i ["metric"] [0] ["amount"]
                columns3["Districts"].append(district)
                columns3["Transaction_count"].append(count)
                columns3["Amount"].append(Amount)
                columns3["States"].append(state)
                columns3["Years"].append(year)
                columns3["Quarter"].append(int(file.strip(".json")))

map_trans = pd.DataFrame(columns3)
map_trans["States"] = map_trans["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
map_trans["States"] = map_trans["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
map_trans["States"] = map_trans["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
map_trans["States"] = map_trans["States"].str.replace("-", " ")
map_trans["States"] = map_trans["States"].str.title()

###############################################################################################################################################################################

#Gathering Map User details
map_user_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/map/user/hover/country/india/state/"
map_user_list = os.listdir(map_user_path)
columns5 = {"States":[], "Years":[], "Quarter":[], "Districts":[], "Registered_users":[], "App": []}
for state in map_user_list:
    map_user_states = map_user_path+ state+ "/"
    map_user_year_list = os.listdir(map_user_states)
    
    for year in map_user_year_list:
        map_user_year = map_user_states+ year+ "/"
        map_user_file_list = os.listdir(map_user_year)

        for file in map_user_file_list:
            map_user_file1 = map_user_year+file
            map_user_read_data = open(map_user_file1, "r")
            map_user_data = json.load(map_user_read_data)
            
            
            for i in map_user_data["data"]["hoverData"].items():
                district = i [0]
                users = i[1]["registeredUsers"]
                appopens = i[1]["appOpens"]
                columns5["Districts"].append(district)
                columns5["Registered_users"].append(users)
                columns5["App"].append(appopens)
                columns5["States"].append(state)
                columns5["Years"].append(year)
                columns5["Quarter"].append(int(file.strip(".json")))
map_user = pd.DataFrame(columns5)
map_user["States"] = map_user["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
map_user["States"] = map_user["States"].str.title()
map_user["States"] = map_user["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
map_user["States"] = map_user["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
map_user["States"] = map_user["States"].str.replace("-", " ")

####################################################################################################################################################################################

#Gathering Map Insurance details
map_insurance_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/map/insurance/hover/country/india/state/"
map_insurance_list = os.listdir(map_insurance_path)
columns6 = {"States":[], "Years":[], "Quarter":[], "Districts":[], "Insurance_count":[], "Insurance_amount": []}
for state in map_insurance_list:
    map_insurance_states = map_insurance_path+ state+ "/"
    map_insurance_year_list = os.listdir(map_insurance_states)
    
    for year in map_insurance_year_list:
        map_insurance_year = map_insurance_states+ year+ "/"
        map_insurance_file_list = os.listdir(map_insurance_year)

        for file in map_insurance_file_list:
            map_insurance_file1 = map_insurance_year+file
            map_insurance_read_data = open(map_insurance_file1, "r")
            map_insurance_data = json.load(map_insurance_read_data)
            
            for i in map_insurance_data["data"]["hoverDataList"]:
                district = i["name"]
                count = i ["metric"] [0] ["count"]
                amount = i ["metric"] [0] ["amount"]
                columns6["Districts"].append(district)
                columns6["Insurance_count"].append(count)
                columns6["Insurance_amount"].append(amount)
                columns6["States"].append(state)
                columns6["Years"].append(year)
                columns6["Quarter"].append(int(file.strip(".json")))

map_insurance = pd.DataFrame(columns6)
map_insurance["States"] = map_insurance["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
map_insurance["States"] = map_insurance["States"].str.replace("andaman-&-nicobar-islands", "Andaman & nicobar islands")
map_insurance["States"] = map_insurance["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
map_insurance["States"] = map_insurance["States"].str.replace("-", " ")
map_insurance["States"] = map_insurance["States"].str.title()   

#################################################################################################################################################################################

#Gathering Top Transaction Details
top_trans_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/top/transaction/country/india/state/"
top_trans_list = os.listdir(top_trans_path)
columns7 = {"States":[], "Years":[], "Quarter":[], "Pincode":[], "Top_trans_count":[], "Top_trans_amount": []}
for state in top_trans_list:
    top_trans_states = top_trans_path+ state+ "/"
    top_trans_year_list = os.listdir(top_trans_states)
    
    for year in top_trans_year_list:
        top_trans_year = top_trans_states+ year+ "/"
        top_trans_file_list = os.listdir(top_trans_year)

        for file in top_trans_file_list:
            top_trans_file1 = top_trans_year+file
            top_trans_read_data = open(top_trans_file1, "r")
            top_trans_data = json.load(top_trans_read_data)

            for i in top_trans_data["data"]["pincodes"]:
                pin_code = i["entityName"]
                top_trans_count = i ["metric"] ["count"]
                top_trans_amount = i ["metric"] ["amount"]
                columns7["Pincode"].append(pin_code)
                columns7["Top_trans_count"].append(top_trans_count)
                columns7["Top_trans_amount"].append(top_trans_amount)
                columns7["States"].append(state)
                columns7["Years"].append(year)
                columns7["Quarter"].append(int(file.strip(".json")))

top_trans = pd.DataFrame(columns7)
top_trans["States"] = top_trans["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
top_trans["States"] = top_trans["States"].str.title()
top_trans["States"] = top_trans["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
top_trans["States"] = top_trans["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
top_trans["States"] = top_trans["States"].str.replace("-", " ")

##################################################################################################################################################################################

#Gathering Top Users Details
top_user_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/top/user/country/india/state/"
top_user_list = os.listdir(top_user_path)
columns8 = {"States":[], "Years":[], "Quarter":[], "Pincode":[], "Registered_users":[]}
for state in top_user_list:
    top_user_states = top_user_path+ state+ "/"
    top_user_year_list = os.listdir(top_user_states)
    
    for year in top_user_year_list:
        top_user_year = top_user_states+ year+ "/"
        top_user_file_list = os.listdir(top_user_year)

        for file in top_user_file_list:
            top_user_file1 = top_user_year+file
            top_user_read_data = open(top_user_file1, "r")
            top_user_data = json.load(top_user_read_data)

            for i in top_user_data["data"]["pincodes"]:
                pin_code = i["name"]
                registered_users = i ["registeredUsers"]
                columns8["Pincode"].append(pin_code)
                columns8["Registered_users"].append(registered_users)
                columns8["States"].append(state)
                columns8["Years"].append(year)
                columns8["Quarter"].append(int(file.strip(".json")))

top_users = pd.DataFrame(columns8)
top_users["States"] = top_users["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
top_users["States"] = top_users["States"].str.title()
top_users["States"] = top_users["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
top_users["States"] = top_users["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
top_users["States"] = top_users["States"].str.replace("-", " ")


################################################################################################################################################################################

#Gathering Top Insurance Details
top_insurance_path = "C:/Users/Shiva Periaswamy/Documents/project/guvi/capstone_project - GuVi - 2/phonepay/pulse/data/top/insurance/country/india/state/"
top_insurance_list = os.listdir(top_insurance_path)
columns9 = {"States":[], "Years":[], "Quarter":[], "Entity_name":[], "Top_insurance_count":[], "Top_insurance_amount": []}
for state in top_insurance_list:
    top_insurance_states = top_insurance_path+ state+ "/"
    top_insurance_year_list = os.listdir(top_insurance_states)
    
    for year in top_insurance_year_list:
        top_insurance_year = top_insurance_states+ year+ "/"
        top_insurance_file_list = os.listdir(top_insurance_year)

        for file in top_insurance_file_list:
            top_insurance_file1 = top_insurance_year+file
            top_insurance_read_data = open(top_insurance_file1, "r")
            top_insurance_data = json.load(top_insurance_read_data)

            for i in top_trans_data["data"]["pincodes"]:
                entity_name = i["entityName"]
                top_insurance_count = i ["metric"] ["count"]
                top_insurance_amount = i ["metric"] ["amount"]
                columns9["Entity_name"].append(pin_code)
                columns9["Top_insurance_count"].append(top_insurance_count)
                columns9["Top_insurance_amount"].append(top_insurance_amount)
                columns9["States"].append(state)
                columns9["Years"].append(year)
                columns9["Quarter"].append(int(file.strip(".json")))

top_insurance = pd.DataFrame(columns9)
top_insurance["States"] = top_insurance["States"].str.replace("dadra-&-nagar-haveli-&-daman-&-diu", "Dadra and nagar haveli and Daman and diu")
top_insurance["States"] = top_insurance["States"].str.title()
top_insurance["States"] = top_insurance["States"].str.replace('andaman-&-nicobar-islands', 'Andaman & nicobar islands')
top_insurance["States"] = top_insurance["States"].str.replace('jammu-&-kashmir', 'Jammu & Kashmir')
top_insurance["States"] = top_insurance["States"].str.replace("-", " ")

# %%
#Creating Aggregate Tables and Data insert
###################################################################################################################################
#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Aggregate Transaction Table
agg_trans_create_query='''create table if not exists Aggregate_transaction(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                transaction_type varchar(255),
                                                                transaction_count bigint,
                                                                transaction_amount bigint)'''
cursor.execute(agg_trans_create_query)
mydb.commit()

agg_trans_insert_query = input_query = '''insert into Aggregate_transaction(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    transaction_type, 
                                                                    transaction_count,
                                                                    transaction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
aggre_trans_insert_data = aggre_transaction.values.tolist()
            
cursor.executemany(agg_trans_insert_query, aggre_trans_insert_data)
mydb.commit()
###############################################################################################################################################


#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Aggregate User Table
aggre_user_create_query='''create table if not exists Aggregate_user(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Brands varchar(255),
                                                                transaction_count bigint,
                                                                Percentage bigint)'''
cursor.execute(aggre_user_create_query)
mydb.commit()

aggre_user_insert_query = input_query = '''insert into Aggregate_user(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Brands, 
                                                                    transaction_count,
                                                                    Percentage)
                                                                values(%s,%s,%s,%s,%s,%s)'''
aggre_user_insert_data = aggre_user.values.tolist()
            
cursor.executemany(aggre_user_insert_query, aggre_user_insert_data)
mydb.commit()

####################################################################################################################################################


#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Aggregate Insurance Table
aggre_insurance_create_query='''create table if not exists Aggregate_insurance(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Payment_type varchar(255),
                                                                transaction_count bigint,
                                                                transaction_amount bigint)'''
cursor.execute(aggre_insurance_create_query)
mydb.commit()

aggre_insurance_insert_query = input_query = '''insert into Aggregate_insurance(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Payment_type, 
                                                                    transaction_count,
                                                                    transaction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
aggre_insurance_insert_data = aggre_insurance.values.tolist()
            
cursor.executemany(aggre_insurance_insert_query, aggre_insurance_insert_data)
mydb.commit()

##############################################################################################################################################################

#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Map Transaction Table
map_trans_create_query='''create table if not exists Map_transaction(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Districts varchar(255),
                                                                transaction_count bigint,
                                                                transaction_amount bigint)'''
cursor.execute(map_trans_create_query)
mydb.commit()

map_trans_insert_query = input_query = '''insert into Map_transaction(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Districts, 
                                                                    transaction_count,
                                                                    transaction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
map_trans_insert_data = map_trans.values.tolist()
            
cursor.executemany(map_trans_insert_query, map_trans_insert_data)
mydb.commit()

#####################################################################################################################################################################
#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Map user Table
map_user_create_query='''create table if not exists Map_users(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Districts varchar(255),
                                                                registeredusers bigint,
                                                                Appopens bigint)'''
cursor.execute(map_user_create_query)
mydb.commit()

map_user_insert_query = input_query = '''insert into Map_users(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Districts, 
                                                                    registeredusers,
                                                                    Appoppens)
                                                                values(%s,%s,%s,%s,%s,%s)'''
map_user_insert_data = map_user.values.tolist()
            
cursor.executemany(map_user_insert_query, map_user_insert_data)
mydb.commit()

##############################################################################################################################################################################

#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Map Insurance Table
map_insurance_create_query='''create table if not exists Map_insurance(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Districts varchar(255),
                                                                transaction_count bigint,
                                                                transaction_amount bigint)'''
cursor.execute(map_insurance_create_query)
mydb.commit()

map_insurance_insert_query = input_query = '''insert into Map_insurance(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Districts, 
                                                                    transaction_count,
                                                                    transaction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
map_insurance_insert_data = map_insurance.values.tolist()
            
cursor.executemany(map_insurance_insert_query, map_insurance_insert_data)
mydb.commit()

##################################################################################################################################################################################

#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#Top Transaction Table
top_trans_create_query='''create table if not exists Top_transaction(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Pincode bigint,
                                                                transaction_count bigint,
                                                                transaction_amount bigint)'''
cursor.execute(top_trans_create_query)
mydb.commit()

top_trans_insert_query = input_query = '''insert into Top_transaction(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    Pincode, 
                                                                    transaction_count,
                                                                    transaction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
top_trans_insert_data = top_trans.values.tolist()
            
cursor.executemany(top_trans_insert_query, top_trans_insert_data)
mydb.commit()

####################################################################################################################################################################################

#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()

#TopUsers Table
top_users_create_query='''create table if not exists top_users(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                Pincode bigint,
                                                                registeredusers bigint)'''
cursor.execute(top_users_create_query)
mydb.commit()

top_users_insert_query = input_query = '''insert into top_users(States , 
                                                                years, 
                                                                Quarter, 
                                                                Pincode, 
                                                                registeredusers)
                                                            values(%s,%s,%s,%s,%s)'''
top_users_insert_data = top_users.values.tolist()
        
cursor.executemany(top_users_insert_query, top_users_insert_data)
mydb.commit()

#####################################################################################################################################################################################

#sql connection
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()


#Top Insurance Table
top_insurance_create_query='''create table if not exists Top_insurance(States varchar(255), 
                                                                years int, 
                                                                Quarter int,
                                                                entity_name bigint,
                                                                transaction_count bigint,
                                                                tranasction_amount bigint)'''
cursor.execute(top_insurance_create_query)
mydb.commit()

top_insurance_insert_query = input_query = '''insert into Top_insurance(States , 
                                                                    years, 
                                                                    Quarter, 
                                                                    entity_name, 
                                                                    transaction_count,
                                                                    tranasction_amount)
                                                                values(%s,%s,%s,%s,%s,%s)'''
top_insurance_insert_data = top_insurance.values.tolist()
            
cursor.executemany(top_insurance_insert_query, top_insurance_insert_data)
mydb.commit()

# %%
# Dataframe Creation
#sql connection
#Fetching Aggregate Transaction DataFrame
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()
cursor.execute("select * from aggregate_transaction")
mydb.commit()
table_agg_transaction = cursor.fetchall()
agg_transaction = pd.DataFrame(table_agg_transaction,columns = ("States" , "years", "Quarter", "transaction_type", "transaction_count","transaction_amount"))
####################################################################################################################################################################

#Fetching Aggregate Users DataFrame
mydb = psycopg2.connect(host = "localhost", user = "postgres", port = "5432", database = "Phonepay_DB", password = "Summer#2024")
cursor = mydb.cursor()
cursor.execute("select * from aggregate_user")
mydb.commit()
table_agg_user = cursor.fetchall()
agg_users = pd.DataFrame(table_agg_user,columns = ("States" , "years", "Quarter", "Brands", "transaction_count","Percentage"))
######################################################################################################################################################################

#Fetching Aggregate Insurance DataFrame
cursor = mydb.cursor()
cursor.execute("select * from aggregate_insurance")
mydb.commit()
table_agg_insurance = cursor.fetchall()
agg_insurance = pd.DataFrame(table_agg_insurance,columns = ("States" , "years", "Quarter", "Payment_type", "transaction_count","transaction_amount"))

#####################################################################################################################################################################

#Fetching Map transaction DataFrame
cursor = mydb.cursor()
cursor.execute("select * from map_transaction")
mydb.commit()
table_map_transaction = cursor.fetchall()
map_transactions = pd.DataFrame(table_map_transaction,columns = ("States" , "years", "Quarter", "Districts", "transaction_count","transaction_amount"))

#######################################################################################################################################################################

#Fetching Map user DataFrame
cursor = mydb.cursor()
cursor.execute("select * from map_users")
mydb.commit()
table_map_users = cursor.fetchall()
map_users1 = pd.DataFrame(table_map_users,columns = ("States" , "years", "Quarter", "Districts", "registeredusers","Appopens"))

#########################################################################################################################################################################

#Fetching Map Insurance DataFrame
cursor = mydb.cursor()
cursor.execute("select * from map_insurance")
mydb.commit()
table_map_insurance = cursor.fetchall()
map_insurance1 = pd.DataFrame(table_map_transaction,columns = ("States" , "years", "Quarter", "Districts", "transaction_count","transaction_amount"))

###############################################################################################################################################################################

#Fetching top transaction DataFrame
cursor = mydb.cursor()
cursor.execute("select * from top_transaction")
mydb.commit()
table_top_transaction = cursor.fetchall()
top_transactions1 = pd.DataFrame(table_top_transaction,columns = ("States" , "years", "Quarter", "Pincode", "transaction_count","transaction_amount"))

#######################################################################################################################################################################

#Fetching top user DataFrame
cursor = mydb.cursor()
cursor.execute("select * from top_users")
mydb.commit()
table_top_users = cursor.fetchall()
top_users1 = pd.DataFrame(table_top_users,columns = ("States" , "years", "Quarter", "Pincode", "registeredusers"))

#########################################################################################################################################################################

#Fetching top Insurance DataFrame
cursor = mydb.cursor()
cursor.execute("select * from top_insurance")
mydb.commit()
table_top_insurance = cursor.fetchall()
top_insurance1 = pd.DataFrame(table_top_insurance,columns = ("States" , "years", "Quarter", "entity_name", "transaction_count","transaction_amount"))

###############################################################################################################################################################################
